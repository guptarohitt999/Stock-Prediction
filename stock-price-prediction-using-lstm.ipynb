# %% [markdown]
# # Stock Prediction

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('GOOG.csv')
df.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # Selecting only date
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head()
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
fg, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(google_stock_data['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()
fg.show()
# Out:
# C:\Users\Rohit Gupta\AppData\Local\Temp\ipykernel_10532\52026741.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fg.show()

# %% [markdown]
# # Data Pre-Processing

# %%
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)

# %%
df.shape
# Out:
# (1258, 2)

# %%
training_size = round(len(df) * 0.80) # Selecting 80% for training and 20% for testing
training_size
# Out:
# 1006

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((1006, 2), (252, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)

# %%
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((956, 50, 2), (956, 2), (202, 50, 2), (202, 2))

# %% [markdown]
# # Creating LSTM model

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 50, 50)            10600
#
#  dropout_1 (Dropout)         (None, 50, 50)            0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=80,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 3s 103ms/step - loss: 4.4544e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0073 - val_mean_absolute_error: 0.0726
# Epoch 2/80
# 30/30 [==============================] - 3s 100ms/step - loss: 4.0110e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0084 - val_mean_absolute_error: 0.0786
# Epoch 3/80
# 30/30 [==============================] - 3s 100ms/step - loss: 4.2735e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0038 - val_mean_absolute_error: 0.0481
# Epoch 4/80
# 30/30 [==============================] - 3s 100ms/step - loss: 3.6474e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0050 - val_mean_absolute_error: 0.0572
# Epoch 5/80
# 30/30 [==============================] - 3s 100ms/step - loss: 3.7551e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0095 - val_mean_absolute_error: 0.0834
# Epoch 6/80
# 30/30 [==============================] - 3s 100ms/step - loss: 3.5530e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0077 - val_mean_absolute_error: 0.0732
# Epoch 7/80
# 30/30 [==============================] - 3s 100ms/step - loss: 3.5956e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0047 - val_mean_absolute_error: 0.0537
# Epoch 8/80
# 30/30 [==============================] - 3s 100ms/step - loss: 3.8417e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0058 - val_mean_absolute_error: 0.0606
# Epoch 9/80
# 30/30 [==============================] - 3s 100ms/step - loss: 3.7341e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0038 - val_mean_absolute_error: 0.0468
# Epoch 10/80
# 30/30 [==============================] - 3s 99ms/step - loss: 3.7195e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0068 - val_mean_absolute_error: 0.0671
# Epoch 11/80
# 30/30 [==============================] - 3s 99ms/step - loss: 3.4495e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0073 - val_mean_absolute_error: 0.0704
# Epoch 12/80
# 30/30 [==============================] - 3s 100ms/step - loss: 3.1949e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0086 - val_mean_absolute_error: 0.0774
# Epoch 13/80
# 30/30 [==============================] - 3s 99ms/step - loss: 3.0912e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0078 - val_mean_absolute_error: 0.0733
# Epoch 14/80
# 30/30 [==============================] - 3s 99ms/step - loss: 3.3689e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0064 - val_mean_absolute_error: 0.0645
# Epoch 15/80
# 30/30 [==============================] - 3s 99ms/step - loss: 3.0259e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0065 - val_mean_absolute_error: 0.0650
# Epoch 16/80
# 30/30 [==============================] - 3s 100ms/step - loss: 3.1526e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0099 - val_mean_absolute_error: 0.0845
# Epoch 17/80
# 30/30 [==============================] - 3s 99ms/step - loss: 3.0877e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0057 - val_mean_absolute_error: 0.0609
# Epoch 18/80
# 30/30 [==============================] - 3s 98ms/step - loss: 2.9670e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0062 - val_mean_absolute_error: 0.0642
# Epoch 19/80
# 30/30 [==============================] - 3s 98ms/step - loss: 2.9973e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0039 - val_mean_absolute_error: 0.0479
# Epoch 20/80
# 30/30 [==============================] - 3s 99ms/step - loss: 2.9964e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0039 - val_mean_absolute_error: 0.0481
# Epoch 21/80
# 30/30 [==============================] - 3s 97ms/step - loss: 2.8012e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0053 - val_mean_absolute_error: 0.0584
# Epoch 22/80
# 30/30 [==============================] - 3s 95ms/step - loss: 2.8037e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0064 - val_mean_absolute_error: 0.0653
# Epoch 23/80
# 30/30 [==============================] - 3s 95ms/step - loss: 2.7595e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0046 - val_mean_absolute_error: 0.0529
# Epoch 24/80
# 30/30 [==============================] - 3s 94ms/step - loss: 2.6363e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0072 - val_mean_absolute_error: 0.0698
# Epoch 25/80
# 30/30 [==============================] - 3s 95ms/step - loss: 2.5964e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0071 - val_mean_absolute_error: 0.0701
# Epoch 26/80
# 30/30 [==============================] - 3s 96ms/step - loss: 2.7090e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0056 - val_mean_absolute_error: 0.0612
# Epoch 27/80
# 30/30 [==============================] - 3s 97ms/step - loss: 2.6580e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0063 - val_mean_absolute_error: 0.0652
# Epoch 28/80
# 30/30 [==============================] - 3s 95ms/step - loss: 2.5782e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0077 - val_mean_absolute_error: 0.0740
# Epoch 29/80
# 30/30 [==============================] - 3s 96ms/step - loss: 2.9716e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0069 - val_mean_absolute_error: 0.0694
# Epoch 30/80
# 30/30 [==============================] - 3s 94ms/step - loss: 2.4133e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0036 - val_mean_absolute_error: 0.0467
# Epoch 31/80
# 30/30 [==============================] - 3s 94ms/step - loss: 2.5334e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0041 - val_mean_absolute_error: 0.0492
# Epoch 32/80
# 30/30 [==============================] - 3s 97ms/step - loss: 2.3614e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0037 - val_mean_absolute_error: 0.0467
# Epoch 33/80
# 30/30 [==============================] - 3s 96ms/step - loss: 2.4924e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0038 - val_mean_absolute_error: 0.0480
# Epoch 34/80
# 30/30 [==============================] - 3s 99ms/step - loss: 2.4247e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0029 - val_mean_absolute_error: 0.0417
# Epoch 35/80
# 30/30 [==============================] - 3s 99ms/step - loss: 2.6967e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0022 - val_mean_absolute_error: 0.0353
# Epoch 36/80
# 30/30 [==============================] - 3s 99ms/step - loss: 2.5344e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0037 - val_mean_absolute_error: 0.0489
# Epoch 37/80
# 30/30 [==============================] - 3s 93ms/step - loss: 2.1801e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0028 - val_mean_absolute_error: 0.0410
# Epoch 38/80
# 30/30 [==============================] - 3s 94ms/step - loss: 2.2123e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0027 - val_mean_absolute_error: 0.0400
# Epoch 39/80
# 30/30 [==============================] - 3s 94ms/step - loss: 2.3179e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0033 - val_mean_absolute_error: 0.0454
# Epoch 40/80
# 30/30 [==============================] - 3s 94ms/step - loss: 2.2197e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0024 - val_mean_absolute_error: 0.0372
# Epoch 41/80
# 30/30 [==============================] - 3s 94ms/step - loss: 2.1179e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0039 - val_mean_absolute_error: 0.0503
# Epoch 42/80
# 30/30 [==============================] - 3s 95ms/step - loss: 2.1148e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0033 - val_mean_absolute_error: 0.0453
# Epoch 43/80
# 30/30 [==============================] - 3s 98ms/step - loss: 2.3545e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0032 - val_mean_absolute_error: 0.0445
# Epoch 44/80
# 30/30 [==============================] - 3s 99ms/step - loss: 2.1641e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0041 - val_mean_absolute_error: 0.0511
# Epoch 45/80
# 30/30 [==============================] - 3s 99ms/step - loss: 2.2742e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0072 - val_mean_absolute_error: 0.0709
# Epoch 46/80
# 30/30 [==============================] - 3s 98ms/step - loss: 1.9145e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0050 - val_mean_absolute_error: 0.0576
# Epoch 47/80
# 30/30 [==============================] - 3s 98ms/step - loss: 1.8606e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0049 - val_mean_absolute_error: 0.0563
# Epoch 48/80
# 30/30 [==============================] - 3s 99ms/step - loss: 1.8298e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0020 - val_mean_absolute_error: 0.0337
# Epoch 49/80
# 30/30 [==============================] - 3s 96ms/step - loss: 1.8595e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0037 - val_mean_absolute_error: 0.0491
# Epoch 50/80
# 30/30 [==============================] - 3s 100ms/step - loss: 2.0254e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0043 - val_mean_absolute_error: 0.0520
# Epoch 51/80
# 30/30 [==============================] - 3s 100ms/step - loss: 1.9065e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0039 - val_mean_absolute_error: 0.0481
# Epoch 52/80
# 30/30 [==============================] - 3s 100ms/step - loss: 1.9023e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0039 - val_mean_absolute_error: 0.0494
# Epoch 53/80
# 30/30 [==============================] - 3s 100ms/step - loss: 1.8444e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0047 - val_mean_absolute_error: 0.0547
# Epoch 54/80
# 30/30 [==============================] - 3s 100ms/step - loss: 1.8290e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0049 - val_mean_absolute_error: 0.0557
# Epoch 55/80
# 30/30 [==============================] - 3s 101ms/step - loss: 1.8217e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0037 - val_mean_absolute_error: 0.0481
# Epoch 56/80
# 30/30 [==============================] - 3s 100ms/step - loss: 1.7578e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0028 - val_mean_absolute_error: 0.0410
# Epoch 57/80
# 30/30 [==============================] - 3s 101ms/step - loss: 1.6989e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0062 - val_mean_absolute_error: 0.0646
# Epoch 58/80
# 30/30 [==============================] - 3s 102ms/step - loss: 1.6862e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0065 - val_mean_absolute_error: 0.0652
# Epoch 59/80
# 30/30 [==============================] - 3s 101ms/step - loss: 1.5641e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0085 - val_mean_absolute_error: 0.0766
# Epoch 60/80
# 30/30 [==============================] - 3s 101ms/step - loss: 1.6507e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0057 - val_mean_absolute_error: 0.0611
# Epoch 61/80
# 30/30 [==============================] - 3s 100ms/step - loss: 1.5651e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0030 - val_mean_absolute_error: 0.0427
# Epoch 62/80
# 30/30 [==============================] - 3s 100ms/step - loss: 1.5866e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0025 - val_mean_absolute_error: 0.0382
# Epoch 63/80
# 30/30 [==============================] - 3s 100ms/step - loss: 1.7004e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0018 - val_mean_absolute_error: 0.0332
# Epoch 64/80
# 30/30 [==============================] - 3s 97ms/step - loss: 1.5784e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0038 - val_mean_absolute_error: 0.0515
# Epoch 65/80
# 30/30 [==============================] - 3s 95ms/step - loss: 1.6846e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0034 - val_mean_absolute_error: 0.0463
# Epoch 66/80
# 30/30 [==============================] - 3s 95ms/step - loss: 1.7542e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0016 - val_mean_absolute_error: 0.0306
# Epoch 67/80
# 30/30 [==============================] - 3s 95ms/step - loss: 1.6046e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0020 - val_mean_absolute_error: 0.0348
# Epoch 68/80
# 30/30 [==============================] - 3s 96ms/step - loss: 1.5660e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0029 - val_mean_absolute_error: 0.0440
# Epoch 69/80
# 30/30 [==============================] - 3s 96ms/step - loss: 1.5709e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0015 - val_mean_absolute_error: 0.0292
# Epoch 70/80
# 30/30 [==============================] - 3s 92ms/step - loss: 1.6705e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0029 - val_mean_absolute_error: 0.0432
# Epoch 71/80
# 30/30 [==============================] - 3s 99ms/step - loss: 1.4171e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0039 - val_mean_absolute_error: 0.0516
# Epoch 72/80
# 30/30 [==============================] - 3s 99ms/step - loss: 1.4569e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0029 - val_mean_absolute_error: 0.0432
# Epoch 73/80
# 30/30 [==============================] - 3s 99ms/step - loss: 1.6446e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0024 - val_mean_absolute_error: 0.0368
# Epoch 74/80
# 30/30 [==============================] - 3s 99ms/step - loss: 1.3367e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0051 - val_mean_absolute_error: 0.0593
# Epoch 75/80
# 30/30 [==============================] - 3s 99ms/step - loss: 1.5570e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0022 - val_mean_absolute_error: 0.0351
# Epoch 76/80
# 30/30 [==============================] - 3s 98ms/step - loss: 1.3810e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0037 - val_mean_absolute_error: 0.0486
# Epoch 77/80
# 30/30 [==============================] - 3s 99ms/step - loss: 1.4655e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0012 - val_mean_absolute_error: 0.0264
# Epoch 78/80
# 30/30 [==============================] - 3s 94ms/step - loss: 1.4048e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0019 - val_mean_absolute_error: 0.0331
# Epoch 79/80
# 30/30 [==============================] - 3s 95ms/step - loss: 1.5649e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0024 - val_mean_absolute_error: 0.0381
# Epoch 80/80
# 30/30 [==============================] - 3s 96ms/step - loss: 1.3949e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0027 - val_mean_absolute_error: 0.0399

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 0s 30ms/step
# array([[0.48668683, 0.48099288],
#        [0.49271974, 0.48732454],
#        [0.49868459, 0.49310195],
#        [0.5166447 , 0.5081993 ],
#        [0.52728635, 0.5187664 ]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted) # Inversing scaling on predicted data
test_inverse_predicted[:5]
# Out:
# array([[1573.2784, 1559.7034],
#        [1584.4629, 1571.4381],
#        [1595.5214, 1582.1456],
#        [1628.818 , 1610.1261],
#        [1648.5468, 1629.7106]], dtype=float32)

# %% [markdown]
# # Visualizing predicted and actual data

# %%
# Merging actual and predicted data for better visualization

gs_slic_data = pd.concat([df.iloc[-202:].copy(),pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=df.iloc[-202:].index)], axis=1)

# %%
gs_slic_data[['open','close']] = MMS.inverse_transform(gs_slic_data[['open','close']]) # Inverse scaling

# %%
gs_slic_data.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-08-24  1593.98  1588.20     1573.278442      1559.703369
# 2020-08-25  1582.07  1608.22     1584.462891      1571.438110
# 2020-08-26  1608.00  1652.38     1595.521362      1582.145630
# 2020-08-27  1653.68  1634.33     1628.817993      1610.126099
# 2020-08-28  1633.49  1644.41     1648.546753      1629.710571

# %%
gs_slic_data[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
gs_slic_data[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# # Predicting upcoming 10 days

# %%
# Creating a dataframe and adding 10 days to existing index 

gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))
# Out:
# C:\Users\Rohit Gupta\AppData\Local\Temp\ipykernel_10532\3062588007.py:3: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))
# C:\Users\Rohit Gupta\AppData\Local\Temp\ipykernel_10532\3062588007.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))

# %%
gs_slic_data['2021-06-09	':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2373.020264      2311.530518
# 2021-06-10  2494.01  2521.60     2377.942627      2322.995117
# 2021-06-11  2524.92  2513.93     2385.927246      2332.277100
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=gs_slic_data.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fg.show()
# Out:
# C:\Users\Rohit Gupta\AppData\Local\Temp\ipykernel_10532\4155468105.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fg.show()

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fg.show()
# Out:
# C:\Users\Rohit Gupta\AppData\Local\Temp\ipykernel_10532\548185773.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fg.show()
